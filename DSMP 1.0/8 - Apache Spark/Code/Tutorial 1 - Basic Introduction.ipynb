# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('D:\Education\Extra\Machine Learning\DSMP 1.0\Apache Spark\Code\Data\Test1.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\axitk\AppData\Local\Temp\ipykernel_17932\864917368.py:1: SyntaxWarning: invalid escape sequence '\E'
#   df = pd.read_csv('D:\Education\Extra\Machine Learning\DSMP 1.0\Apache Spark\Code\Data\Test1.csv')

# %%
df.head()
# Out:
#      Name  cgpa  packages  placement
# 0    Axit   8.0       4.2          1
# 1  Bhavik   8.5       4.2          1
# 2    Ravi   7.5       5.0          0
# 3    Meet   8.5       5.0          1
# 4   Ankit   6.0       4.0          0

# %%
print("SPARK_HOME:", os.environ.get("SPARK_HOME"))
print("JAVA_HOME:", os.environ.get("JAVA_HOME"))
# Out:
# SPARK_HOME: C:\spark\spark-4.0.1-bin-hadoop3
# JAVA_HOME: C:\Program Files\Eclipse Adoptium\jdk-17.0.17.10-hotspot

# %%
#importing a pyspark
from pyspark.sql import SparkSession

# %%
# Create Spark session
spark = SparkSession.builder \
    .appName("MySparkApp") \
    .master("local[*]") \
    .getOrCreate()

# Print Spark version to confirm
print("Spark Version:", spark.version)
# Out:
# Spark Version: 4.0.1

# %%
# Test DataFrame
data = [("Axit", 8.0), ("Bhavik", 8.5)]
columns = ["Name", "CGPA"]
df = spark.createDataFrame(data, columns)
df.show()
# Out:
# +------+----+
# |  Name|CGPA|
# +------+----+
# |  Axit| 8.0|
# |Bhavik| 8.5|
# +------+----+

# %%
#read a data set in a spark

df_pyspark = spark.read.csv('D:\Education\Extra\Machine Learning\DSMP 1.0\Apache Spark\Code\Data\Test1.csv')
df_pyspark.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\axitk\AppData\Local\Temp\ipykernel_17932\1587696871.py:3: SyntaxWarning: invalid escape sequence '\E'
#   df_pyspark = spark.read.csv('D:\Education\Extra\Machine Learning\DSMP 1.0\Apache Spark\Code\Data\Test1.csv')
# +-------+----+--------+---------+
# |    _c0| _c1|     _c2|      _c3|
# +-------+----+--------+---------+
# |   Name|cgpa|packages|placement|
# |   Axit|   8|     4.2|        1|
# | Bhavik| 8.5|     4.2|        1|
# |   Ravi| 7.5|       5|        0|
# |   Meet| 8.5|       5|        1|
# |  Ankit|   6|       4|        0|
# |Divyesh| 8.3|       5|        1|
# +-------+----+--------+---------+

# %%
df_pyspark  = spark.read.option('header','true').csv('D:\Education\Extra\Machine Learning\DSMP 1.0\Apache Spark\Code\Data\Test1.csv')
df_pyspark.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# <>:1: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\axitk\AppData\Local\Temp\ipykernel_17932\3807453293.py:1: SyntaxWarning: invalid escape sequence '\E'
#   df_pyspark  = spark.read.option('header','true').csv('D:\Education\Extra\Machine Learning\DSMP 1.0\Apache Spark\Code\Data\Test1.csv')
# +-------+----+--------+---------+
# |   Name|cgpa|packages|placement|
# +-------+----+--------+---------+
# |   Axit|   8|     4.2|        1|
# | Bhavik| 8.5|     4.2|        1|
# |   Ravi| 7.5|       5|        0|
# |   Meet| 8.5|       5|        1|
# |  Ankit|   6|       4|        0|
# |Divyesh| 8.3|       5|        1|
# +-------+----+--------+---------+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.connect.dataframe.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Axit', cgpa='8', packages='4.2', placement='1'),
#  Row(Name='Bhavik', cgpa='8.5', packages='4.2', placement='1'),
#  Row(Name='Ravi', cgpa='7.5', packages='5', placement='0')]

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- cgpa: string (nullable = true)
#  |-- packages: string (nullable = true)
#  |-- placement: string (nullable = true)

# %%
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 spark.stop()
#
# NameError: name 'spark' is not defined
