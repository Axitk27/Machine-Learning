# %%
# use python to solve all the questions
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### Q1. Given the vectors A = [1, 2, 3] and B = [4, 5, 6], calculate the element-wise product of the two vectors.

# %%
A = np.array([1,2,3])
B = np.array([4,5,6])

A*B
# np.dot(A,B)
# Out:
# array([ 4, 10, 18])

# %% [markdown]
# ### Q2. Find the magnitude of the vector C = [2, -3, 1].

# %%
C = np.array([2,-3,1])

np.linalg.norm(C)
# Out:
# np.float64(3.7416573867739413)

# %% [markdown]
# ### Q3. Given the vectors D = [1, 2, 3] and E = [4, 5, 6], calculate the cosine of the angle between them.

# %%
D = np.array([1,2,3])
E = np.array([4,5,6])

np.dot(D,E)/(np.linalg.norm(D)*np.linalg.norm(E))
# Out:
# np.float64(0.9746318461970762)

# %% [markdown]
# ### Q4. Given the vectors F = [1, 2, 3] and G = [4, 5, 6], calculate the cross product of the two vectors.

# %%
F = np.array([1,2,3])
G = np.array([4,5,6])

np.cross(F,G)
# Out:
# array([-3,  6, -3])

# %% [markdown]
# ### Q5. Given the vector H = [2, 4, 6], shift the vector +1 unit in each dimension

# %%
[3,5,7]

# %% [markdown]
# ### Q6. Given the vectors I = [1, 2, 3] and J = [4, 5, 6], calculate the projection of vector I onto vector J.

# %%
import numpy as np

I = np.array([1, 2, 3])
J = np.array([4, 5, 6])

projection_I_onto_J = (np.dot(I, J) / np.dot(J, J)) * J

print(projection_I_onto_J)
# Out:
# [1.66233766 2.07792208 2.49350649]

# %% [markdown]
# ### Q7. Consider the 2D - position vector a = (1, 3). If b is the point (5, 4), find the vector `ab` and the vector sum `a + ab`. Provide a sketch plot.
#
# Note: Search for quiver, to plot an arrow.

# %%
a = np.array([1,3])
b = np.array([5,4])
xo= np.array([0,0])
p = a*b
q = a + a*b

# %%
plt.figure()
plt.quiver(xo[0], xo[1], a[0], a[1], angles='xy', scale_units='xy', scale=1,label = 'a')
plt.quiver(xo[0], xo[1], b[0], b[1], angles='xy', scale_units='xy', scale=1,label = 'b')
plt.quiver(xo[0], xo[1], p[0], p[1], angles='xy', scale_units='xy', scale=1,label = 'p')
plt.quiver(xo[0], xo[1], q[0], q[1], angles='xy', scale_units='xy', scale=1,label = 'q')
plt.xlim(-1, 20)
plt.ylim(-1, 20)
plt.gca().set_aspect('equal')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Q8. Given two 2D vectors `u` and `v` where `u = [-1, 4]` and `v = [3, -2]`, find the dot product `u . v`, the angle between `u` and `v`, and the projection of `u` onto `v`.

# %%
u = np.array([-1,4])
v = np.array([3,-2])

p = np.dot(u,v)

angle_red = math.acos(p/(np.linalg.norm(u)*np.linalg.norm(v)) )
angle_degree = math.degrees(angle_red)

# %%
p/(np.linalg.norm(u)*np.linalg.norm(v))
# Out:
# np.float64(-0.7399400733959438)

# %% [markdown]
# ### Q9. Given a hyperplane defined by the equation 3x - 2y + z = 1, find two different points that lie on this hyperplane.

# %%
[0,0,1]
[1/3,0,0]
[1,1,0]
[0,1,3]

# %% [markdown]
# ### Q10. Find a nearest point from a given array of points to a point P1.
# P1 - (3,9,3)
#
# Array of points :
# ```
# [[1, 8, 5],
# [8, 8, 2],
# [7, 9, 1],
# [5, 6, 3],
# [9, 1, 2],
# [6, 5, 9],
# [5, 8, 6],
# [3, 4, 8],
# [6, 8, 4],
# [7, 2, 7]]
# ```

# %%
P = np.array([3,9,3])
q = np.array([[1, 8, 5],
       [8, 8, 2],
       [7, 9, 1],
       [5, 6, 3],
       [9, 1, 2],
       [6, 5, 9],
       [5, 8, 6],
       [3, 4, 8],
       [6, 8, 4],
       [7, 2, 7]])

# %%
distances = np.linalg.norm(q - p, axis=1)
# Find index of point with shortest distance
index_min_distance = np.argmin(distances)

point_min_distance = q[index_min_distance]
distances
# Out:
# array([27.58622845, 29.84962311, 29.46183973, 27.22131518, 26.70205985,
#        30.7408523 , 30.09983389, 27.96426291, 29.58039892, 28.58321186])

# %%
# Generate array of 10 random 3-D points
points = np.array([[1, 8, 5],
       [8, 8, 2],
       [7, 9, 1],
       [5, 6, 3],
       [9, 1, 2],
       [6, 5, 9],
       [5, 8, 6],
       [3, 4, 8],
       [6, 8, 4],
       [7, 2, 7]])

# Define target point
target = np.array([3, 9, 3])

# Calculate distances between target point and each point in the array
distances = np.linalg.norm(points - target, axis=1)

# Find index of point with shortest distance
index_min_distance = np.argmin(distances)

# Retrieve point with shortest distance
point_min_distance = points[index_min_distance]

print("Nearest point:", point_min_distance)
index_min_distance
# Out:
# Nearest point: [1 8 5]
# np.int64(0)
