# %%
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv('Characters.csv',encoding='latin1')
df2 = pd.read_csv('Movies.csv',encoding='latin1')

# %%
df1.head()#It will give the top four row output
# Out:
#    ï»¿Movie ID                                Movie Title  Release Year  \
# 0            1   Harry Potter and the Philosopher's Stone          2001
# 1            2    Harry Potter and the Chamber of Secrets          2002
# 2            3   Harry Potter and the Prisoner of Azkaban          2004
# 3            4        Harry Potter and the Goblet of Fire          2005
# 4            5  Harry Potter and the Order of the Phoenix          2007
#
#    Runtime         Budget       Box Office
# 0      152  $125,000,000   $1,002,000,000
# 1      161  $100,000,000     $880,300,000
# 2      142  $130,000,000     $796,700,000
# 3      157  $150,000,000     $896,400,000
# 4      138  $150,000,000     $942,000,000

# %%
#You will work on left to right catogerical data

# %% [markdown]
# # Catogorical Data

# %%
df1.shape
# Out:
# (8, 6)

# %%
#Count Plot
#Finding the count in frequency
sns.countplot(df1,x = 'Gender')
#df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='House', ylabel='count'>

# %%
#Pie Plot
#Finding the count in percentage
df1['Species'].value_counts().plot(kind='pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Plot

# %%
#(1)Histogram
#to behave nimirical data behave into the categorical data
#Create a range and then plot the data

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df2['Budget'],bins=10)#bins will change the distribution of the data
# Out:
# (array([1., 0., 1., 0., 1., 0., 2., 0., 2., 1.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
#Distplot
#Update version of the Histogram
sns.distplot(df['Age'])
#It will give me the probablity of the number
# Out:
# C:\Users\axitk\AppData\Local\Temp\ipykernel_16132\1086238651.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# C:\Users\axitk\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#BoxPlot
#Five number of theory will use to find out the outlier
#To remove out the noise data
sns.boxplot(df['Budget'])
# Out:
# <Axes: >

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
#Number >0 Positively skew
#Number <0 Negativaly skew
